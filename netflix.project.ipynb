# %% [markdown]
# # Task 1. Data Immersion and Wrangling

# %% [markdown]
# # step 1: Data Access and Familiarisation

# %% [markdown]
# ## 1.1 Load the Dataset

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
#  ## 1.2 Check the  structure

# %%
df.shape
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# ...

# %% [markdown]
# # step 2: Data Quality Assessment

# %% [markdown]
# ## 2.1 check missing values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
#  ## 2.2 Check duplicates  and replace it

# %%
def clean_data(df):

    df = df.drop_duplicates()
    df['date_added'] = pd.to_datetime(df['date_added'],errors = 'coerce')
    df['country'] = df['country'].fillna('Unknown')
    df['director'] = df['director'].fillna('Unknown')

    return df

# %% [markdown]
#  ## 2.3 Dataset Size Before and After Cleaning

# %%
rows_before = df.shape[0]

df_clean = clean_data(df)

rows_after = df_clean.shape[0]

print("Rows before cleaning:", rows_before)
print("Rows after cleaning:", rows_after)
print("Duplicates removed:", rows_before - rows_after)
# Out:
# Rows before cleaning: 8807
# Rows after cleaning: 8807
# Duplicates removed: 0

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ### Distribution of Movies vs TV Shows on Netflix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='type', data=df)
plt.title("Movies vs TV Shows on Netflix")
plt.show()

# %%
df['release_year'].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ### Netflix Content Growth Over the Years

# %%
df['release_year'].value_counts().sort_index().plot()
plt.title('Netflix Content Growth Over Years')
plt.show()

# %% [markdown]
# ### Top 10 Countries Producing Netflix Content

# %%
df['country'].value_counts().head(10).plot(kind = 'bar')
plt.title('top 10 countries on Netflix')
plt.show()

# %% [markdown]
# ### Top Genres on Netflix

# %%
df['genres'] = df['listed_in'].str.split(', ')
df = df.explode('genres')

df['genres'].value_counts().head(10).plot(kind='bar')
plt.title('Top Genres on Netflix')
plt.show()

# %% [markdown]
# ### Content Recommendation Based on Genre

# %%
def recommend(title,df):
    genre = df[df['title']== title]['listed_in'].values[0]
    recommendations = df[df['listed_in']==genre]['title'].head(5)
    return recommendations

# %%
recommend("Narcos", df)
# Out:
# 2415    Queen of the South
# 2415    Queen of the South
# 2415    Queen of the South
# 2415    Queen of the South
# 2415    Queen of the South
# Name: title, dtype: object

# %%
df
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# ...      ...      ...                   ...              ...
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.size
# Out:
# 1653171

# %% [markdown]
# ### Export Cleaned Dataset to CSV File

# %%
df.to_csv('final_netflix.csv', index=False)
